# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data=pd.read_csv("wind.data", sep="\s+", parse_dates=[[0,1,2]])
data.head(100)
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# 0  2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1  2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 2  2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 3  2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 4  2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ..        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 95 2061-04-06   4.50   8.21   9.29   3.21   5.96   4.33   5.00   7.33   6.13
# 96 2061-04-07   8.21   7.04  13.75   3.75   6.00   5.00   5.33   4.00   5.66
# 97 2061-04-08  10.34  11.29  11.29   4.42   9.38   7.67   8.71  10.08   9.21
# 98 2061-04-09  13.37  11.12  13.08   8.83  11.75  10.21   9.96   9.59  10.54
# 99 2061-04-10   5.75   4.83   8.25   3.00   5.88   4.25   5.21   3.58   6.00
#
#       CLO    BEL    MAL
# ...

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
def fixcentury(x):
    temp_year=x.year
    if x.year>2000:
        temp_year= x.year -100 
    else:
         x.year
    return datetime.date(temp_year,x.month,x.day)

data["Yr_Mo_Dy"]=data["Yr_Mo_Dy"].apply(fixcentury)
data.head(10)
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
# 5  1961-01-06  13.21   8.12   9.96   6.67   5.37  4.50  10.67   4.42   7.17
# 6  1961-01-07  13.50  14.29   9.50   4.96  12.29  8.33   9.17   9.29   7.58
# 7  1961-01-08  10.96   9.75   7.62   5.91   9.62  7.29  14.29   7.62   9.25
# 8  1961-01-09  12.58  10.83  10.00   4.75  10.37  6.79   8.04  10.13   7.79
# 9  1961-01-10  13.37  11.12  19.50   8.33   9.71  6.54  11.42   7.79   8.54
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# ...

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data['Yr_Mo_Dy']=pd.to_datetime(data['Yr_Mo_Dy'])
data.set_index('Yr_Mo_Dy')
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# ...

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# Yr_Mo_Dy    0
# RPT         6
# VAL         3
# ROS         2
# KIL         5
# SHA         2
# BIR         0
# DUB         3
# CLA         2
# MUL         3
# CLO         1
# BEL         0
# MAL         4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.notnull().sum()
# Out:
# Yr_Mo_Dy    6574
# RPT         6568
# VAL         6571
# ROS         6572
# KIL         6569
# SHA         6572
# BIR         6574
# DUB         6571
# CLA         6572
# MUL         6571
# CLO         6573
# BEL         6574
# MAL         6570
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.sum().sum()/data.notna().sum().sum()
# Out:
# /var/folders/cv/5d9pcgmx1c7gkjn0tsj4dy0m0000gq/T/ipykernel_82743/422784508.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.sum().sum()/data.notna().sum().sum()
# 9.440837986211093

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
data.describe(percentiles=[])
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# min       0.000000     0.000000     0.000000     0.000000     0.040000
# 50%       6.830000     9.210000     8.080000     8.170000     8.290000
# ...

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats=pd.DataFrame()
day_stats['min']=data.min(axis=1)
day_stats['max']=data.max(axis=1)
day_stats['mean']=data.mean(axis=1)
day_stats['std']=data.std(axis=1)
day_stats
# Out:
# /var/folders/cv/5d9pcgmx1c7gkjn0tsj4dy0m0000gq/T/ipykernel_82743/4132310395.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   day_stats['min']=data.min(axis=1)
# /var/folders/cv/5d9pcgmx1c7gkjn0tsj4dy0m0000gq/T/ipykernel_82743/4132310395.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   day_stats['max']=data.max(axis=1)
# /var/folders/cv/5d9pcgmx1c7gkjn0tsj4dy0m0000gq/T/ipykernel_82743/4132310395.py:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   day_stats['mean']=data.mean(axis=1)
# ...

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
data.index = pd.date_range(start='1960-01-01', end='1990-1-1', periods=len(data))
data.loc[data.index.month == 1].mean()
# Out:
# /var/folders/cv/5d9pcgmx1c7gkjn0tsj4dy0m0000gq/T/ipykernel_82743/640676702.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.loc[data.index.month == 1].mean()
# RPT    12.301339
# VAL    10.473018
# ROS    11.585223
# KIL     6.200660
# SHA    10.127728
# BIR     7.119430
# DUB     9.451105
# CLA     8.384089
# MUL     8.263725
# CLO     8.649429
# BEL    12.804563
# MAL    14.807746
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data.index = pd.date_range(start='1960-01-01', end='1990-1-1', periods=len(data))
data.groupby(data.index.to_period('A')).mean()
# Out:
# /var/folders/cv/5d9pcgmx1c7gkjn0tsj4dy0m0000gq/T/ipykernel_82743/176538438.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(data.index.to_period('A')).mean()
#             RPT        VAL        ROS       KIL        SHA        BIR  \
# 1960  11.781659  10.353624  10.963333  6.855714  10.665505   7.717318
# 1961  13.591759  10.858119  12.459450  7.362765  11.563973   8.060046
# 1962  10.980457   9.237123  10.785708  6.479224  10.004703   6.660137
# 1963  13.898493  11.300411  13.762374  8.017260  11.981233   9.116301
# 1964  12.089087  10.472192  11.459132  6.731050  11.270776   7.741005
# 1965  12.297900  11.012831  12.294018  7.203105  12.081187   7.906393
# 1966  12.477169  11.050502  12.373333  6.380594  10.567808   7.062740
# ...

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
data.index = pd.date_range(start='1960-01-01', end='1990-1-1', periods=len(data))
data.groupby(data.index.to_period('M')).mean()
# Out:
# /var/folders/cv/5d9pcgmx1c7gkjn0tsj4dy0m0000gq/T/ipykernel_82743/2565501807.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(data.index.to_period('M')).mean()
#                RPT        VAL        ROS       KIL        SHA        BIR  \
# 1960-01  13.475263  10.429444  12.177368  6.370526   8.632353   6.535789
# 1960-02  16.911250  14.657059  14.453529  9.214706  14.140588  10.924706
# 1960-03  16.084737  14.632632  14.643158  9.453889  13.330000  11.225263
# 1960-04  12.290588  13.125556  12.188824  7.834444  12.281111   9.831667
# 1960-05  10.648421   9.924211  10.028947  7.173889   9.857368   8.578421
# ...            ...        ...        ...       ...        ...        ...
# 1989-09   9.472222   9.276111   9.260000  4.652778   8.360556   6.849444
# ...

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
data.index = pd.date_range(start='1960-01-01', end='1990-1-1', periods=len(data))
data.groupby(data.index.to_period('W')).mean()
# Out:
# /var/folders/cv/5d9pcgmx1c7gkjn0tsj4dy0m0000gq/T/ipykernel_82743/2342827123.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(data.index.to_period('W')).mean()
#                            RPT      VAL      ROS     KIL        SHA      BIR  \
# 1959-12-28/1960-01-03  14.8750  14.9600  12.0000  7.8950  12.620000   8.7700
# 1960-01-04/1960-01-10  13.9050  11.2200  11.3650  6.8875   7.947500   5.4400
# 1960-01-11/1960-01-17  12.1980  11.1720  11.0080  5.3480  10.140000   7.2400
# 1960-01-18/1960-01-24  12.6875   7.7375  11.4475  4.1350   5.667500   3.7325
# 1960-01-25/1960-01-31  14.7300  10.2700  15.2700  8.6050   9.656667   8.4375
# ...                        ...      ...      ...     ...        ...      ...
# ...

# %% [markdown]
# ### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
week_data=data.resample('W').agg(['min','max','mean','std'])
week_data.loc[week_data.index[1:53],"RPL":"MAL"]
# Out:
# /var/folders/cv/5d9pcgmx1c7gkjn0tsj4dy0m0000gq/T/ipykernel_82743/2787959927.py:1: FutureWarning: ['Yr_Mo_Dy'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   week_data=data.resample('W').agg(['min','max','mean','std'])
# Empty DataFrame
# Columns: []
# ...
